# %%
#Import 
import pandas as pd
import numpy as np

# %%
#File Infomation
name   = 'yoshiyama'
time   = 1800
low    = 0
#up = 0.27
folder = r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー'
data_path = folder + '\\'+ name + '_datalist.xlsx'
#data      = pd.read_excel(data_path, sheet_name=4,header=None,skiprows=1)
data      = pd.read_excel(data_path)
#print(data_path)
#print(data)

# %% [markdown]
# #EEGspec
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
#
# # ここにグラフを描画する処理を記載する
# fig = plt.figure()
#
# df = data.iloc[:,:int(time/300)+1]
#
# x1 = df.iloc[6:31:,0]    #横軸データ
# x1_label = r'周波数[Hz]'   #第1横軸ラベル
# x1_lim = [8, 30]      #第1横軸範囲
#
# y1 = np.sqrt(df.iloc[6:31,1:int(time/300)+1])
# y1.columns =['-'.join([str(i*5),str((i+1)*5)]) for i in range(int(time/300))]
#   #第1縦軸ラベル
# y1_lim = [0, 0.1]
#
# ax1 = fig.add_subplot(111)
# for i in range(int(len(y1.columns))):
#     ax1.plot(x1, y1.iloc[:,i],label=y1.columns[i], linestyle='-', marker='None')
#
# h1, l1 = ax1.get_legend_handles_labels()
# ax1.legend(h1, l1, loc='upper right')
# ax1.set_xlabel(x1_label)    #第1横軸ラベル
# ax1.set_xlim(x1_lim)  #第1横軸範囲
# ax1.set_ylabel('power_spectrum')    #第1縦軸ラベル
# ax1.axvspan(8.0,13.0,color="gray",alpha=0.3)
# #ax1.set_ylim(y1_lim)
# ax1.grid(True)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\\'+ name +'_spec.png', dpi=300)

# %% [markdown]
# #x2 = data['時間[s]']   #第2横軸データ
#
#  #第1データ
#
#
# y2 = data['KSS[-]']     #第2データ
# y2_label = r'KSS評価値[-]'#第2縦軸ラベル
# y2_lim = [1, 9]
#
# ax1 = fig.add_subplot(111)
#
# ln1=ax1.plot(x1, y1,label=y1_label, linestyle='-', marker='None', color='C0')  #第1データ
#
# ax2 = ax1.twinx()   #第2縦軸生成
#
# ln2=ax2.plot(x1, y2,label=y2_label, linestyle='None',marker='.', color='C2')    #第1データ
#
# h1, l1 = ax1.get_legend_handles_labels()
# h2, l2 = ax2.get_legend_handles_labels()
# ax1.legend(h1+h2, l1+l2, loc='lower right')
#
# ax1.set_xlabel(x1_label)    #第1横軸ラベル
# ax1.set_xlim(x1_lim)  #第1横軸範囲
# ax1.set_xticks(np.arange(0, time+1, step= 300))
# ax1.set_ylabel(y1_label)    #第1縦軸ラベル
# ax1.set_ylim(y1_lim)
# ax1.grid(True)
# ax2.set_ylabel(y2_label)     #第2縦軸ラベル
# ax2.set_ylim(y2_lim)
#
# #plt.plot(x1,y1)
# #plt.plot(x2,y2)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\Pupil\\'+ name +'_puil.png', dpi=300)

# %% [markdown]
# #pupilMPF
# %matplotlib inline
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# # ここにグラフを描画する処理を記載する
#
# fig = plt.figure()
#
# df = pd.concat([data['KSS[-]'],data['瞳孔径_MPF[Hz]']],axis=1)
# df = df[:time+1]
# print(df)
# sns.violinplot(x='KSS[-]',y='瞳孔径_MPF[Hz]',data=df, scale='width', inner='quartile')
#
# plt.xlabel('KSS評価値[-]')
# plt.ylabel('瞳孔径_MPF[Hz]')
# y_lim = [0, 35]
# plt.ylim(y_lim)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\Pupil\\'+ name +'_Pupil_bio.png', dpi=300,bbox_inches="tight")

# %% [markdown]
# #pupilMPF
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
#
# # ここにグラフを描画する処理を記載する
# fig = plt.figure()
#
# x1 = data['時間[s]']    #横軸データ
# x1_label = r'時間[s]'   #第1横軸ラベル
# x1_lim = [0, time]      #第1横軸範囲
# #x2 = data['時間[s]']   #第2横軸データ
#
# y1 = data['瞳孔径_MPF[Hz]'].rolling(60).mean() #第1データ
# y1_label = r'瞳孔径_MPF[Hz]'   #第1縦軸ラベル
# y1_lim = [low, low+30]
#
# y2 = data['KSS[-]']     #第2データ
# y2_label = r'KSS評価値[-]'#第2縦軸ラベル
# y2_lim = [1, 9]
#
# ax1 = fig.add_subplot(111)
#
# ln1=ax1.plot(x1, y1,label=y1_label, linestyle='-', marker='None', color='C0')  #第1データ
#
# ax2 = ax1.twinx()   #第2縦軸生成
#
# ln2=ax2.plot(x1, y2,label=y2_label, linestyle='None',marker='.', color='C2')    #第1データ
#
# h1, l1 = ax1.get_legend_handles_labels()
# h2, l2 = ax2.get_legend_handles_labels()
# ax1.legend(h1+h2, l1+l2, loc='lower right')
#
# ax1.set_xlabel(x1_label)    #第1横軸ラベル
# ax1.set_xlim(x1_lim)  #第1横軸範囲
# ax1.set_xticks(np.arange(0, time+1, step= 300))
# ax1.set_ylabel(y1_label)    #第1縦軸ラベル
# ax1.set_ylim(y1_lim)
# ax1.grid(True)
# ax2.set_ylabel(y2_label)     #第2縦軸ラベル
# ax2.set_ylim(y2_lim)
#
# #plt.plot(x1,y1)
# #plt.plot(x2,y2)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\Pupil\\'+ name +'_puil.png', dpi=300)

# %% [markdown]
# #pupilMPF
# %matplotlib inline
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# # ここにグラフを描画する処理を記載する
#
# fig = plt.figure()
#
# df = pd.concat([data['KSS[-]'],data['瞳孔径_MPF[Hz]']],axis=1)
# df = df[:time+1]
# print(df)
# sns.violinplot(x='KSS[-]',y='瞳孔径_MPF[Hz]',data=df, scale='width', inner='quartile')
#
# plt.xlabel('KSS評価値[-]')
# plt.ylabel('瞳孔径_MPF[Hz]')
# y_lim = [0, 35]
# plt.ylim(y_lim)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\Pupil\\'+ name +'_Pupil_bio.png', dpi=300,bbox_inches="tight")

# %% [markdown]
# #pupil
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
#
# # ここにグラフを描画する処理を記載する
# fig = plt.figure()
#
# x1 = data['時間[s]']    #横軸データ
# x1_label = r'時間[s]'   #第1横軸ラベル
# x1_lim = [0, time]      #第1横軸範囲
# #x2 = data['時間[s]']   #第2横軸データ
#
# y1 = data['瞳孔径[px]'].rolling(60).mean() #第1データ
# y1_label = r'瞳孔径[px]'   #第1縦軸ラベル
# y1_lim = [low, low+15]
#
# y2 = data['KSS[-]']     #第2データ
# y2_label = r'KSS評価値[-]'#第2縦軸ラベル
# y2_lim = [1, 9]
#
# ax1 = fig.add_subplot(111)
#
# ln1=ax1.plot(x1, y1,label=y1_label, linestyle='-', marker='None', color='C0')  #第1データ
#
# ax2 = ax1.twinx()   #第2縦軸生成
#
# ln2=ax2.plot(x1, y2,label=y2_label, linestyle='None',marker='.', color='C2')    #第1データ
#
# h1, l1 = ax1.get_legend_handles_labels()
# h2, l2 = ax2.get_legend_handles_labels()
# ax1.legend(h1+h2, l1+l2, loc='lower right')
#
# ax1.set_xlabel(x1_label)    #第1横軸ラベル
# ax1.set_xlim(x1_lim)  #第1横軸範囲
# ax1.set_xticks(np.arange(0, time+1, step= 300))
# ax1.set_ylabel(y1_label)    #第1縦軸ラベル
# ax1.set_ylim(y1_lim)
# ax1.grid(True)
# ax2.set_ylabel(y2_label)     #第2縦軸ラベル
# ax2.set_ylim(y2_lim)
#
# #plt.plot(x1,y1)
# #plt.plot(x2,y2)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\Pupil\\'+ name +'_puil.png', dpi=300)

# %% [markdown]
# #EEG_hakohige
# %matplotlib inline
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# # ここにグラフを描画する処理を記載する
#
# fig = plt.figure()
#
# df = pd.concat([data['KSS[-]'],data['瞳孔径[px]']],axis=1)
# df = df[:time+1]
# print(df)
# sns.violinplot(x='KSS[-]',y='瞳孔径[px]',data=df, scale='width', inner='quartile')
#
# plt.xlabel('KSS評価値[-]')
# plt.ylabel('瞳孔径[px]')
# y_lim = [25, 65]
# plt.ylim(y_lim)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\Pupil\\'+ name +'_Pupil_bio.png', dpi=300,bbox_inches="tight")

# %% [markdown]
# #EEG_hakohige
# %matplotlib inline
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# # ここにグラフを描画する処理を記載する
#
# fig = plt.figure()
#
# df = pd.concat([data['KSS[-]'],data['O1_MPF[Hz]']],axis=1)
# df = df[:time+1]
# print(df)
# sns.violinplot(x='KSS[-]',y='O1_MPF[Hz]',data=df, scale='width', inner='quartile')
#
# plt.xlabel('KSS評価値[-]')
# plt.ylabel('EEG_MPF[Hz]')
# y_lim = [10, 35]
# plt.ylim(y_lim)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\EEG_MPF\\'+ name +'_EEG_bio.png', dpi=300,bbox_inches="tight")

# %% [markdown]
# #EEG_alpha_beta
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
#
# # ここにグラフを描画する処理を記載する
# fig = plt.figure()
#
# x1 = ['-'.join([str(i*5),str((i+1)*5)]) for i in range(int(time/300))]    #横軸データ
# x1_label = r'時間[min]'   #第1横軸ラベル
# x2 = np.array([i for i in range(int(time/300))])   #第2横軸データ
#
# roll1 = data['O1_alpha_ratio[-]'].rolling(300).mean()
# y1 = [roll1.iloc[(i+1)*300] for i in range(int(time/300))]
# y1_label = r'α波比率[-]'   #第1縦軸ラベル
# y1_lim = [low, low+0.15]
#
# roll2 = data['O1_beta_ratio[-]']
# y2 = [roll2.iloc[(i+1)*300] for i in range(int(time/300))]
# y2_label = r'β波比率[-]'#第2縦軸ラベル
# y2_lim = [up, up+0.15]
#
# roll3 = data['KSS[-]']
# y3 = [roll3.iloc[(i+1)*300] for i in range(int(time/300))]
# y3_label = r'KSS評価値[-]'#第2縦軸ラベル
# y3_lim = [1, 9]
#
#
# ax1 = fig.add_subplot(111)
# ln1= ax1.bar(x2-0.2, y1,label=y1_label, color='C0',width=0.4)  #第1データ
#
# ax2 = ax1.twinx()
# ln2= ax2.bar(x2+0.2, y2,label=y2_label, color='C1',width=0.4)  #第1データ
#
# ax3 = ax1.twinx()   #第2縦軸生成
# ln3=ax3.plot(x2, y3,label=y3_label, linestyle='-',marker='.', color='C2')    #第1データ
#
# h1, l1 = ax1.get_legend_handles_labels()
# h2, l2 = ax2.get_legend_handles_labels()
# h3, l3 = ax3.get_legend_handles_labels()
#
# ax1.set_xlabel(x1_label)    #第1横軸ラベル
# #ax1.set_xlim(x1_lim)  #第1横軸範囲
#
# ax1.set_ylabel(y1_label)    #第1縦軸ラベル
# ax1.set_ylim(y1_lim)
# ax1.grid(False)
#
# ax2.set_ylabel(y2_label)
# ax2.set_ylim(y2_lim)
#
# ax3.set_ylabel(y3_label)     #第2縦軸ラベル
# ax3.spines["right"].set_position(("axes", 1.18))
# ax3.set_ylim(y3_lim)
#
# #fig.subplots_adjust(left=0, right=1, bottom=0.2, top=0.8)
# ax1.legend(h1+h2+h3, l1+l2+l3, loc='upper right')
# plt.xticks(x2,x1)
# #plt.plot(x1,y1)
# #plt.plot(x2,y2)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\EEG_ab\\'+ name +'_EEGab.png', dpi=300,bbox_inches="tight")

# %% [markdown]
# #EEG_MPF
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
#
# # ここにグラフを描画する処理を記載する
# fig = plt.figure()
#
# x1 = ['-'.join([str(i*5),str((i+1)*5)]) for i in range(int(time/300))]    #横軸データ
# x1_label = r'時間[min]'   #第1横軸ラベル
#
# roll1 = data['O1_MPF[Hz]'].rolling(300).mean()
# y1 = [roll1.iloc[(i+1)*300] for i in range(int(time/300))]
# y1_label = r'EEG_MPF[Hz]'   #第1縦軸ラベル
# y1_lim = [low, low+8]
#
# roll2 = data['KSS[-]']
# y2 = [roll2.iloc[(i+1)*300] for i in range(int(time/300))]
# y2_label = r'KSS評価値[-]'#第2縦軸ラベル
# y2_lim = [1, 9]
#
# ax1 = fig.add_subplot(111)
#
# ln1=ax1.bar(x1, y1,label=y1_label, width=0.4)  #第1データ
#
# ax2 = ax1.twinx()   #第2縦軸生成
#
# ln2=ax2.plot(x1, y2,label=y2_label, linestyle='-',marker='.', color='C2')    #第1データ
#
# h1, l1 = ax1.get_legend_handles_labels()
# h2, l2 = ax2.get_legend_handles_labels()
# ax1.legend(h1+h2, l1+l2, loc='lower right')
#
# ax1.set_xlabel(x1_label)    #第1横軸ラベル
# #ax1.set_xlim(x1_lim)  #第1横軸範囲
# #ax1.set_xticks(np.arange(0, time+1, step= 300))
# ax1.set_ylabel(y1_label)    #第1縦軸ラベル
# ax1.set_ylim(y1_lim)
# ax1.grid(False)
# ax2.set_ylabel(y2_label)     #第2縦軸ラベル
# ax2.set_ylim(y2_lim)
#
# #plt.plot(x1,y1)
# #plt.plot(x2,y2)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\EEG_MPF\\'+ name +'_EEGMPF1.png', dpi=300)

# %% [markdown]
# #EEG_MPF
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
#
# # ここにグラフを描画する処理を記載する
# fig = plt.figure()
#
# x1 = data['時間[s]']    #横軸データ
# x1_label = r'時間[s]'   #第1横軸ラベル
# x1_lim = [0, time]      #第1横軸範囲
# #x2 = data['時間[s]']   #第2横軸データ
#
# y1 = data['O1_MPF[Hz]'].rolling(60).mean() #第1データ
# y1_label = r'EEG_MPF[Hz]'   #第1縦軸ラベル
# y1_lim = [low, low+8]
#
# y2 = data['KSS[-]']     #第2データ
# y2_label = r'KSS評価値[-]'#第2縦軸ラベル
# y2_lim = [1, 9]
#
# ax1 = fig.add_subplot(111)
#
# ln1=ax1.plot(x1, y1,label=y1_label, linestyle='-', marker='None', color='C0')  #第1データ
#
# ax2 = ax1.twinx()   #第2縦軸生成
#
# ln2=ax2.plot(x1, y2,label=y2_label, linestyle='None',marker='.', color='C2')    #第1データ
#
# h1, l1 = ax1.get_legend_handles_labels()
# h2, l2 = ax2.get_legend_handles_labels()
# ax1.legend(h1+h2, l1+l2, loc='lower right')
#
# ax1.set_xlabel(x1_label)    #第1横軸ラベル
# ax1.set_xlim(x1_lim)  #第1横軸範囲
# ax1.set_xticks(np.arange(0, time+1, step= 300))
# ax1.set_ylabel(y1_label)    #第1縦軸ラベル
# ax1.set_ylim(y1_lim)
# ax1.grid(True)
# ax2.set_ylabel(y2_label)     #第2縦軸ラベル
# ax2.set_ylim(y2_lim)
#
# #plt.plot(x1,y1)
# #plt.plot(x2,y2)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\EEG_MPF\\'+ name +'_EEGMPF.png', dpi=300)

# %% [markdown]
# #EEG_alpha_beta
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
#
# # ここにグラフを描画する処理を記載する
# fig = plt.figure()
#
# x1 = data['時間[s]']    #横軸データ
# x1_label = r'時間[s]'   #第1横軸ラベル
# x1_lim = [0, time]      #第1横軸範囲
# #x2 = data['時間[s]']   #第2横軸データ
#
# y1 = data['O1_alpha_ratio[-]'].rolling(60).mean() #第1データ
# y1_label = r'α波比率[-]'   #第1縦軸ラベル
# y1_lim = [low, low+0.15]
# y3 = data['O1_beta_ratio[-]'].rolling(60).mean() #第1データ
# y3_label = r'β波比率[-]'   #第1縦軸ラベル
# y3_lim = [up, up+0.15]
#
# y2 = data['KSS[-]']     #第2データ
# y2_label = r'KSS評価値[-]'#第2縦軸ラベル
# y2_lim = [1, 9]
#
# ax1 = fig.add_subplot(111)
# ln1=ax1.plot(x1, y1,label=y1_label, linestyle='-', marker='None', color='C0')  #第1データ
#
# ax3 = ax1.twinx()
# ln3=ax3.plot(x1, y3,label=y3_label, linestyle='-', marker='None', color='C1')  #第1データ
#
# ax2 = ax1.twinx()   #第2縦軸生成
# ln2=ax2.plot(x1, y2,label=y2_label, linestyle='None',marker='.', color='C2')    #第1データ
#
#
#
# h1, l1 = ax1.get_legend_handles_labels()
# h2, l2 = ax2.get_legend_handles_labels()
# h3, l3 = ax3.get_legend_handles_labels()
# ax1.legend(h1+h3+h2, l1+l3+l2, loc='lower right')
#
# ax1.set_xlabel(x1_label)    #第1横軸ラベル
# ax1.set_xlim(x1_lim)  #第1横軸範囲
# ax1.set_xticks(np.arange(0, time+1, step= 300))
# ax1.set_ylabel(y1_label)    #第1縦軸ラベル
#
# ax1.set_ylim(y1_lim)
#
#
# ax1.grid(True)
#
# ax3.set_ylabel(y3_label)
#
# ax3.set_ylim(y3_lim)
#
#
# ax2.set_ylabel(y2_label)     #第2縦軸ラベル
# ax2.spines["right"].set_position(("axes", 1.18))
# ax2.set_ylim(y2_lim)
#
# #fig.subplots_adjust(left=0, right=1, bottom=0.2, top=0.8)
#
# #plt.plot(x1,y1)
# #plt.plot(x2,y2)
# fig.savefig(r'D:\iriwa\デスクトップ\Code\Project_Python\Research\新しいフォルダー\EEG_ab\\'+ name +'_EEGab.png', dpi=300,bbox_inches="tight")
